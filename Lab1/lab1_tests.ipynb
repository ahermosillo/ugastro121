# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# import ugradio

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.load('lab1_dat1.npy')
# Out:
# array([-13312,  -9728,  29952, ...,   1536,  21248, -32512], dtype=int16)

# %%
arr1 = np.load('lab1_dat1.npy')[:800]
len(arr1)
# Out:
# 800

# %%
plt.figure(figsize = (12,8))
plt.plot(arr1)

# %%
1/800.
# Out:
# 0.00125
